# %% [markdown]
# <a href="https://colab.research.google.com/github/rsadaphule/jhu-cv/blob/main/JHU_CV_Homwork4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 4 - AutoEncoders
#
# ## This code does the following:
#
# * Loads and preprocesses the MNIST dataset.
# * Defines a 3-layer perceptron autoencoder.
# * Trains the autoencoder with a specified number of hidden units.
# * Plots the learning curves for both training and validation loss.
# * Visualizes the weights of the hidden units as 28x28 images.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, losses, datasets
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load MNIST dataset
(train_images, y_train), (test_images, y_test) = datasets.mnist.load_data()

# %%
# Normalize and flatten the images
train_images = train_images.astype('float32') / 255.
test_images = test_images.astype('float32') / 255.
train_images = train_images.reshape((len(train_images), np.prod(train_images.shape[1:])))
test_images = test_images.reshape((len(test_images), np.prod(test_images.shape[1:])))

# %%
# Define the autoencoder model
def build_autoencoder(hidden_units):
    input_img = layers.Input(shape=(784,))
    encoded = layers.Dense(hidden_units, activation='relu')(input_img)
    decoded = layers.Dense(784, activation='sigmoid')(encoded)
    autoencoder = models.Model(input_img, decoded)
    autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())
    return autoencoder

# %%
hidden_units = 10 # Example for 10 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)

# %%
# Train the autoencoder
history_unit_10 = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))

# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_10.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0882 - val_loss: 0.0575
# Epoch 2/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0513 - val_loss: 0.0449
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0419 - val_loss: 0.0388
# Epoch 4/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0375 - val_loss: 0.0357
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0354 - val_loss: 0.0345
# Epoch 6/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0344 - val_loss: 0.0337
# Epoch 7/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0338 - val_loss: 0.0331
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0332 - val_loss: 0.0326
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0328 - val_loss: 0.0322
# Epoch 10/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0324 - val_loss: 0.0318
# Epoch 11/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0320 - val_loss: 0.0315
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0317 - val_loss: 0.0312
# Epoch 13/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0315 - val_loss: 0.0310
# Epoch 14/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0313 - val_loss: 0.0308
# Epoch 15/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0311 - val_loss: 0.0306
# Epoch 16/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0310 - val_loss: 0.0305
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0308 - val_loss: 0.0304
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0307 - val_loss: 0.0303
# Epoch 19/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0306 - val_loss: 0.0302
# Epoch 20/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0305 - val_loss: 0.0301
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0305 - val_loss: 0.0300
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0304 - val_loss: 0.0300
# Epoch 23/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0303 - val_loss: 0.0299
# Epoch 24/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0303 - val_loss: 0.0299
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0302 - val_loss: 0.0298
# Epoch 26/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0302 - val_loss: 0.0298
# Epoch 27/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0301 - val_loss: 0.0297
# Epoch 28/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0301 - val_loss: 0.0297
# Epoch 29/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0301 - val_loss: 0.0297
# Epoch 30/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0300 - val_loss: 0.0297
# Epoch 31/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0300 - val_loss: 0.0296
# Epoch 32/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0300 - val_loss: 0.0296
# Epoch 33/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0300 - val_loss: 0.0295
# Epoch 34/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 35/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 36/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 38/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0299 - val_loss: 0.0295
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 40/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 41/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 42/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 43/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 45/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 46/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0298 - val_loss: 0.0294
# Epoch 47/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0297 - val_loss: 0.0294
# Epoch 48/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0297 - val_loss: 0.0293
# Epoch 49/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0297 - val_loss: 0.0294
# Epoch 50/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0297 - val_loss: 0.0293
# Model saved to autoencoder_model_unit_10.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
hidden_units = 5 # Example for 5 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)
history_unit_5 = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))
# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_5.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 8ms/step - loss: 0.0959 - val_loss: 0.0682
# Epoch 2/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0620 - val_loss: 0.0562
# Epoch 3/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0526 - val_loss: 0.0495
# Epoch 4/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0490 - val_loss: 0.0476
# Epoch 5/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0475 - val_loss: 0.0465
# Epoch 6/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0465 - val_loss: 0.0457
# Epoch 7/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0458 - val_loss: 0.0451
# Epoch 8/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0453 - val_loss: 0.0447
# Epoch 9/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0448 - val_loss: 0.0443
# Epoch 10/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0445 - val_loss: 0.0440
# Epoch 11/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0442 - val_loss: 0.0437
# Epoch 12/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0440 - val_loss: 0.0435
# Epoch 13/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0438 - val_loss: 0.0433
# Epoch 14/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0436 - val_loss: 0.0432
# Epoch 15/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0434 - val_loss: 0.0430
# Epoch 16/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0433 - val_loss: 0.0429
# Epoch 17/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0432 - val_loss: 0.0428
# Epoch 18/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0431 - val_loss: 0.0427
# Epoch 19/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0430 - val_loss: 0.0426
# Epoch 20/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0429 - val_loss: 0.0425
# Epoch 21/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0429 - val_loss: 0.0425
# Epoch 22/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0428 - val_loss: 0.0424
# Epoch 23/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0427 - val_loss: 0.0423
# Epoch 24/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0427 - val_loss: 0.0423
# Epoch 25/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0426 - val_loss: 0.0423
# Epoch 26/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0426 - val_loss: 0.0422
# Epoch 27/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0426 - val_loss: 0.0422
# Epoch 28/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0425 - val_loss: 0.0422
# Epoch 29/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0425 - val_loss: 0.0421
# Epoch 30/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0425 - val_loss: 0.0421
# Epoch 31/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0425 - val_loss: 0.0420
# Epoch 32/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 33/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 34/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 35/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 36/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0424 - val_loss: 0.0420
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0423 - val_loss: 0.0420
# Epoch 38/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 39/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 40/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 41/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 42/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 43/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 44/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0419
# Epoch 45/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0423 - val_loss: 0.0418
# Epoch 46/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0422 - val_loss: 0.0419
# Epoch 47/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0422 - val_loss: 0.0418
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0422 - val_loss: 0.0418
# Epoch 49/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0422 - val_loss: 0.0418
# Epoch 50/50
# 235/235 [==============================] - 1s 5ms/step - loss: 0.0422 - val_loss: 0.0418
# Model saved to autoencoder_model_unit_5.h5

# %%
hidden_units = 20 # Example for 60 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)
history = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))

# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_20.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0763 - val_loss: 0.0474
# Epoch 2/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0410 - val_loss: 0.0357
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0328 - val_loss: 0.0294
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0275 - val_loss: 0.0252
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0245 - val_loss: 0.0231
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0228 - val_loss: 0.0218
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0217 - val_loss: 0.0209
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0209 - val_loss: 0.0201
# Epoch 9/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0202 - val_loss: 0.0195
# Epoch 10/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0196 - val_loss: 0.0189
# Epoch 11/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0190 - val_loss: 0.0184
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0187 - val_loss: 0.0181
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0180 - val_loss: 0.0175
# Epoch 16/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 17/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0178 - val_loss: 0.0173
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 19/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0176 - val_loss: 0.0172
# Epoch 20/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 23/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 24/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 25/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 26/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 27/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0174 - val_loss: 0.0169
# Epoch 28/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 30/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 31/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 32/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0173 - val_loss: 0.0168
# Epoch 33/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 34/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 35/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 36/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0172 - val_loss: 0.0168
# Epoch 38/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 39/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 40/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 41/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 42/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 43/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 44/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 45/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 46/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0167
# Epoch 47/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 48/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 49/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 50/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0170 - val_loss: 0.0166
# Model saved to autoencoder_model_unit_20.h5

# %%
hidden_units = 30 # Example for 30 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)
history_unit_30 = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))
# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_30.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 10ms/step - loss: 0.0711 - val_loss: 0.0421
# Epoch 2/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0360 - val_loss: 0.0305
# Epoch 3/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0275 - val_loss: 0.0242
# Epoch 4/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0225 - val_loss: 0.0204
# Epoch 5/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0191 - val_loss: 0.0172
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0165 - val_loss: 0.0152
# Epoch 7/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0149 - val_loss: 0.0139
# Epoch 8/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0137 - val_loss: 0.0130
# Epoch 9/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0129 - val_loss: 0.0123
# Epoch 10/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0124 - val_loss: 0.0119
# Epoch 11/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0120 - val_loss: 0.0116
# Epoch 12/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0118 - val_loss: 0.0114
# Epoch 13/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0116 - val_loss: 0.0112
# Epoch 14/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0115 - val_loss: 0.0111
# Epoch 15/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0114 - val_loss: 0.0111
# Epoch 16/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0113 - val_loss: 0.0110
# Epoch 17/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0113 - val_loss: 0.0109
# Epoch 18/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 19/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 20/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 21/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 22/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 23/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 24/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 25/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0111 - val_loss: 0.0108
# Epoch 26/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 27/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 28/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 29/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 30/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 31/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 32/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 33/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0110 - val_loss: 0.0107
# Epoch 34/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0107
# Epoch 35/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 36/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 37/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 38/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 39/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 40/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 41/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0109 - val_loss: 0.0106
# Epoch 42/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0106
# Epoch 43/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0106
# Epoch 44/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 45/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0106
# Epoch 46/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 47/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 48/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0108 - val_loss: 0.0105
# Epoch 50/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0108 - val_loss: 0.0105
# Model saved to autoencoder_model_unit_30.h5

# %%
hidden_units = 60 # Example for 60 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)
history_unit_60 = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))

# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_60.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 9ms/step - loss: 0.0604 - val_loss: 0.0329
# Epoch 2/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0266 - val_loss: 0.0213
# Epoch 3/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0186 - val_loss: 0.0156
# Epoch 4/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0141 - val_loss: 0.0121
# Epoch 5/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0111 - val_loss: 0.0096
# Epoch 6/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 7/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 8/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0067 - val_loss: 0.0061
# Epoch 9/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 10/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0056 - val_loss: 0.0052
# Epoch 11/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0053 - val_loss: 0.0050
# Epoch 12/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 13/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 14/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 15/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 16/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0045
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 18/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 19/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 20/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 21/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0044 - val_loss: 0.0043
# Epoch 22/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 23/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 24/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 25/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 26/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 27/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 28/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 29/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 30/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 31/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 32/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 34/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 35/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 36/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 37/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 38/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 39/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 40/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 41/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 42/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 43/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 44/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 45/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 46/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 47/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 48/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 49/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0041 - val_loss: 0.0040
# Epoch 50/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0041 - val_loss: 0.0040
# Model saved to autoencoder_model_unit_60.h5

# %%
hidden_units = 120 # Example for 60 hidden units, repeat for other sizes
autoencoder = build_autoencoder(hidden_units)
history_unit_120 = autoencoder.fit(train_images, train_images,
                          epochs=50,
                          batch_size=256,
                          shuffle=True,
                          validation_data=(test_images, test_images))

# Save the trained autoencoder model to a file
model_save_path = 'autoencoder_model_unit_120.h5'  # Specify the path where you want to save the model
autoencoder.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Epoch 1/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0511 - val_loss: 0.0245
# Epoch 2/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0184 - val_loss: 0.0134
# Epoch 3/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0113 - val_loss: 0.0091
# Epoch 4/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0081 - val_loss: 0.0069
# Epoch 5/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 6/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 7/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0044 - val_loss: 0.0040
# Epoch 8/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 9/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0035 - val_loss: 0.0032
# Epoch 10/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 12/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 13/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 14/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 15/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 17/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 18/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 19/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 20/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 21/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 22/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 23/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 24/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 25/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 26/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 27/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 28/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 29/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 30/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 31/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 32/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 33/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 34/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 35/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 36/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 37/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 38/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 39/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 40/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 41/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 42/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 43/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 44/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 45/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 46/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 47/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 48/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 49/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 50/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0016 - val_loss: 0.0017
# Model saved to autoencoder_model_unit_120.h5

# %%
# Plot learning curves
hidden_units=["5", "10", "30", "60", "120"]
#hidden_units = ["10"]
models = ["autoencoder_model_unit_5.h5", "autoencoder_model_unit_10.h5", "autoencoder_model_unit_30.h5", "autoencoder_model_unit_60.h5", "autoencoder_model_unit_120.h5"]
#models = [  "autoencoder_model_unit_10.h5" ]
histories = [history_unit_5, history_unit_10, history_unit_30, history_unit_60, history_unit_120]
# Load the autoencoder model from the file
counter=0
for model_path in models:
  model = load_model(model_path)
  print(f"****** Learning curver for model with hidden units {hidden_units[counter]} *******")
  # Plot learning curves
  plt.figure(figsize=(10, 4))
  plt.plot(histories[counter].history['loss'], label='Training loss')
  plt.plot(histories[counter].history['val_loss'], label='Validation loss')
  plt.title('Learning Curves')
  plt.xlabel('Epochs')
  plt.ylabel('MSE Loss')
  plt.legend()
  plt.show()
  counter=counter+1
# Out:
# ****** Learning curver for model with hidden units 5 *******
# ****** Learning curver for model with hidden units 10 *******
# ****** Learning curver for model with hidden units 30 *******
# ****** Learning curver for model with hidden units 60 *******
# ****** Learning curver for model with hidden units 120 *******

# %% [markdown]
# Summary of loss vs Hidden unit size
# ```
# Hiddent Unit Size.    | Validation loss
# ----------------------|---------------
# 5                     | 0.0418
# 10                    | 0.0293
# 30                    | 0.01015
# 60                    | 0.0040
# 120                   | 0.0017
# ```
# As you can see the model with 120 unit hindden size offers lowest loss and hence highest performance

# %%
# Filter out images of digit '3'
test_images = test_images[y_test == 3]

# %%
# Assuming 'loaded_autoencoder' is your loaded model
# Note: Ensure the image is correctly preprocessed (flattened, normalized) as per your model's training
#reconstructed_image = loaded_autoencoder.predict(image_of_digit_3.reshape(1, 784))
def display_image(input_image, output_image):
  plt.figure(figsize=(6, 3))
  plt.subplot(1, 2, 1)
  plt.imshow(input_image.squeeze(), cmap='gray')
  plt.title('Original Image')
  plt.axis('off')
# Reconstructed image
  plt.subplot(1, 2, 2)
  plt.imshow(output_image.squeeze().reshape(28, 28), cmap='gray')
  plt.title('Reconstructed Image')
  plt.axis('off')
  plt.show()

# %%
from tensorflow.keras import models, layers, losses, datasets
from tensorflow.keras.models import load_model

hidden_units=["5", "10", "30", "60", "120"]
#hidden_units = ["10"]
models = ["autoencoder_model_unit_5.h5", "autoencoder_model_unit_10.h5", "autoencoder_model_unit_30.h5", "autoencoder_model_unit_60.h5", "autoencoder_model_unit_120.h5"]
#models = [  "autoencoder_model_unit_10.h5" ]

# Load the autoencoder model from the file
counter=0
for model_path in models:
  model = load_model(model_path)
  # Use the model to reconstruct the images of digit '3'
  reconstructed_images = model.predict(test_images)
  # Calculate the Mean Squared Error (MSE) between original and reconstructed images
  mse = np.mean(np.square(test_images - reconstructed_images))
  print(f"******** Displaying stats for model with hidden units {hidden_units[counter]} ********")
  print(f"Hidden Units : {model_path},  MSE for the model: {mse}")
  display_image(test_images[0].reshape(1, 28, 28), reconstructed_images[0])
  counter = counter + 1
# Out:
# 32/32 [==============================] - 0s 2ms/step
# ******** Displaying stats for model with hidden units 5 ********
# Hidden Units : autoencoder_model_unit_5.h5,  MSE for the model: 0.046010542660951614
# 32/32 [==============================] - 0s 2ms/step
# ******** Displaying stats for model with hidden units 10 ********
# Hidden Units : autoencoder_model_unit_10.h5,  MSE for the model: 0.031169669702649117
# 32/32 [==============================] - 0s 2ms/step
# ******** Displaying stats for model with hidden units 30 ********
# Hidden Units : autoencoder_model_unit_30.h5,  MSE for the model: 0.011346012353897095
# 32/32 [==============================] - 0s 2ms/step
# ******** Displaying stats for model with hidden units 60 ********
# Hidden Units : autoencoder_model_unit_60.h5,  MSE for the model: 0.004602301865816116
# 32/32 [==============================] - 0s 3ms/step
# ******** Displaying stats for model with hidden units 120 ********
# Hidden Units : autoencoder_model_unit_120.h5,  MSE for the model: 0.0018522478640079498

# %% [markdown]
# #Conclusion
# ## Autoencoder with 120 units performs best. The quality of recostructed images looks a lot better with hidden units = 120 and also validation loss is lowest.
#
# ## As number of hidden units increases, the loss improves and reconstruction quality improves as well

# %%
# Visualize the weights for 10 and 20 hidden units
hidden_units=[10, 20]
#hidden_units = ["10"]
models = ["autoencoder_model_unit_10.h5", "autoencoder_model_unit_20.h5"]
#models = [  "autoencoder_model_unit_10.h5" ]
counter=0
for model_path in models:
  model = load_model(model_path)
  weights = model.layers[1].get_weights()[0]  # Get weights of the encoded layer
  n = min(10, hidden_units[counter])  # Display this many digits
  print(f"******** Displaying weights for model with hidden units {hidden_units[counter]} ********")
  # Plot the weights
  plt.figure(figsize=(20, 4))
  for i in range(n):
      ax = plt.subplot(1, n, i + 1)
      plt.imshow(weights[:, i].reshape(28, 28), cmap='viridis')
      plt.title(f'Neuron {i + 1}')
      plt.axis('off')
  plt.show()
  counter = counter + 1
# Out:
# ******** Displaying weights for model with hidden units 10 ********
# ******** Displaying weights for model with hidden units 20 ********
